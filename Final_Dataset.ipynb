# %% [markdown]
# <a href="https://colab.research.google.com/github/jayasurya2701/AI-Driven-Guest-Experience-for-Personalization-System-for-Hosipitality/blob/main/Final_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("Final_dataset.csv", encoding='ISO-8859-1')
data
# Out:
#       S.No.    Customer Name              Customer Mail ID  Unnamed: 3  \
# 0         1      James Craig              fmills@yahoo.com         NaN
# 1         2  Michelle Rhodes      karenyates@robinson.info         NaN
# 2         3   Yvonne Alvarez        reedcharles@davis.info         NaN
# 3         4       Jamie Pham           zbowers@aguirre.com         NaN
# 4         5    Vickie George              ssmith@yahoo.com         NaN
# ...     ...              ...                           ...         ...
# 9995   9996        Todd York      sanchezkaitlyn@yahoo.com         NaN
# 9996   9997      Vernon King  crystalthompson@chandler.com         NaN
# 9997   9998    Stephen Dixon            markclay@yahoo.com         NaN
# 9998   9999     Brian Bishop          smithisaac@gmail.com         NaN
# 9999  10000   Ellen Castillo            icoleman@yahoo.com         NaN
#
#          Date and Time                                             Review  \
# ...

# %%
# Drop the "Unnamed: 3" column
data = data.loc[:, ~data.columns.str.contains('^Unnamed')]

# %%
data.columns
data
# Out:
#       S.No.    Customer Name              Customer Mail ID     Date and Time  \
# 0         1      James Craig              fmills@yahoo.com  15-03-2024 18:31
# 1         2  Michelle Rhodes      karenyates@robinson.info  31-03-2024 06:27
# 2         3   Yvonne Alvarez        reedcharles@davis.info  29-04-2024 06:37
# 3         4       Jamie Pham           zbowers@aguirre.com  17-07-2024 03:25
# 4         5    Vickie George              ssmith@yahoo.com  08-02-2024 13:19
# ...     ...              ...                           ...               ...
# 9995   9996        Todd York      sanchezkaitlyn@yahoo.com  01-10-2024 07:16
# 9996   9997      Vernon King  crystalthompson@chandler.com  07-01-2024 02:56
# 9997   9998    Stephen Dixon            markclay@yahoo.com  30-11-2024 15:14
# 9998   9999     Brian Bishop          smithisaac@gmail.com  08-12-2024 05:31
# 9999  10000   Ellen Castillo            icoleman@yahoo.com  02-05-2024 10:03
#
# ...

# %%
data.head(10)
# Out:
#    S.No.        Customer Name           Customer Mail ID     Date and Time  \
# 0      1          James Craig           fmills@yahoo.com  15-03-2024 18:31
# 1      2      Michelle Rhodes   karenyates@robinson.info  31-03-2024 06:27
# 2      3       Yvonne Alvarez     reedcharles@davis.info  29-04-2024 06:37
# 3      4           Jamie Pham        zbowers@aguirre.com  17-07-2024 03:25
# 4      5        Vickie George           ssmith@yahoo.com  08-02-2024 13:19
# 5      6    Theresa Velazquez            wolson@hall.biz  31-12-2023 11:36
# 6      7          Paul Howard        jaredchen@yahoo.com  05-12-2024 12:04
# 7      8        Henry Leonard        amber96@hotmail.com  25-07-2024 16:30
# 8      9     Jackie Hansen MD       cooperlori@gmail.com  19-12-2023 17:06
# 9     10  Jennifer Stephenson  amymunoz@chandler-lee.com  20-05-2024 21:57
#
#                                               Review  Server Name  \
# 0  nice hotel expensive parking got good deal sta...  Christopher
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   S.No.              10000 non-null  int64
#  1   Customer Name      10000 non-null  object
#  2   Customer Mail ID   10000 non-null  object
#  3   Date and Time      10000 non-null  object
#  4   Review             10000 non-null  object
#  5   Server Name        10000 non-null  object
#  6   Server EMPID       10000 non-null  object
#  7   Customer Age       10000 non-null  int64
#  8   Dining Preference  10000 non-null  object
#  9   Room Preference    10000 non-null  object
#  10  Sports Activity    10000 non-null  object
#  11  Wellness           10000 non-null  object
#  12  Pricing Pattern    10000 non-null  object
# dtypes: int64(2), object(11)
# memory usage: 1015.8+ KB
